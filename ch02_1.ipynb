# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/lena256.jpga')
print(img.shape)
# Out:
# (256, 256, 3)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
R_img, G_img, B_img = cv2.split(img)

# %%
print(R_img.shape)
# Out:
# (256, 256)

# %%
Cimg = RGB_img

# %%
Cimg[:, :, 0] = R_img
Cimg[:, :, 1] = R_img
Cimg[:, :, 2] = R_img

# %%
Cimg[:, :, 0] = B_img
Cimg[:, :, 1] = B_img
Cimg[:, :, 2] = B_img

# %%
Cimg[:, :, 0] = G_img
Cimg[:, :, 1] = G_img
Cimg[:, :, 2] = G_img

# %%
plt.imshow(Cimg)

# %%
HSV_img = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2HSV)

# %%
H_img, S_img, V_img = cv2.split(HSV_img)
Cimg[:, :, 0] = H_img
Cimg[:, :, 1] = H_img
Cimg[:, :, 2] = H_img
plt.imshow(HSV_img)

# %%
H_img, S_img, V_img = cv2.split(HSV_img)
Cimg[:, :, 0] = H_img
Cimg[:, :, 1] = H_img
Cimg[:, :, 2] = H_img
plt.imshow(HSV_img)
