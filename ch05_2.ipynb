# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np
import cv2
import matplotlib.pyplot as plt

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/winter.jpg')
print(img.shape)
gimg=cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
#plt.imshow(gimg1, cmap='gray')
cv2_imshow(gimg)
# Out:
# (200, 252, 3)
# <PIL.Image.Image image mode=L size=252x200>

# %%
outimg = cv2.blur(gimg, (7,7))
cv2_imshow(outimg)
# Out:
# <PIL.Image.Image image mode=L size=252x200>

# %%
outimg = cv2.GaussianBlur(gimg, (7,7), 5)
cv2_imshow(outimg)
# Out:
# <PIL.Image.Image image mode=L size=252x200>

# %%
outimg = cv2.medianBlur(gimg, 7)
cv2_imshow(outimg)
# Out:
# <PIL.Image.Image image mode=L size=252x200>

# %%
outimage = gimg.copy()
#blurimage = cv2.GaussianBlur(outimage, (7,7), 5)
blurimage = cv2.medianBlur(outimage, 7)


x = 115
y= 90
size = 15


for h in range (y, y+size):
  for w in range (x, x+size):
    #outimage[h,w] = 255
    outimage[h][w] = blurimage[h][w]

cv2_imshow(outimage)
# Out:
# <PIL.Image.Image image mode=L size=252x200>

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/lena256.jpg')
print(img.shape)
gimg=cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
#plt.imshow(gimg1, cmap='gray')
cv2_imshow(gimg)
# Out:
# (256, 256, 3)
# <PIL.Image.Image image mode=L size=256x256>

# %%
outimg = cv2.GaussianBlur(gimg, (7,7), 2)
cv2_imshow(outimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
edgeimage= cv2.addWeighted(gimg, 1, outimg, -1, 0)
cv2_imshow(edgeimage)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
unsahrpimage= cv2.addWeighted(gimg, 1, edgeimage, -1, 0)
cv2_imshow(unsahrpimage)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernnel3 = np.ones((3,3), np.float32)/9
kernnel3[0][0] = -1/9
kernnel3[0][1] = -1/9
kernnel3[0][2] = -1/9
kernnel3[1][0] = -1/9
kernnel3[1][1] =  17/9
kernnel3[1][2] = -1/9
kernnel3[2][0] = -1/9
kernnel3[2][1] = -1/9
kernnel3[2][2] = -1/9

# %%
output = cv2.filter2D(gimg, -1, kernnel3)
cv2_imshow(output)
# Out:
# <PIL.Image.Image image mode=L size=256x256>
