# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
import numpy as np
import cv2
import matplotlib.pyplot as plt

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/char.bmp')
print(img.shape)
gimg=cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
plt.imshow(gimg, cmap='gray')
#cv2_imshow(gimg)
# Out:
# (256, 256, 3)

# %%
kernel1 = np.ones((5,5),np.uint8)
dilateimg = cv2.dilate(gimg,kernel1,iterations = 1)
cv2_imshow(dilateimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
edgeimg = dilateimg - gimg
cv2_imshow(edgeimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/milkdrop.bmp')
print(img.shape)
gimg=cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
plt.imshow(gimg, cmap='gray')
#cv2_imshow(gimg)
# Out:
# (256, 256, 3)

# %%
kernel1 = np.ones((3,3),np.uint8)
dilateimg = cv2.dilate(gimg,kernel1,iterations = 5)
cv2_imshow(dilateimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
gBin = np.zeros((gimg.shape[0], gimg.shape[1]), dtype=np.uint8)

# %%
threshold = 120

for i in range (gimg.shape[0]):
  for j in range (gimg.shape[1]):
    if gimg[i,j] >threshold:
      gBin[i,j] = 255

cv2_imshow(gBin)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
kernel1 = np.ones((3,3),np.uint8)
dilateimg = cv2.dilate(gBin,kernel1,iterations = 3)
cv2_imshow(dilateimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
#kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3,3))
#kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3,3))
kernel = cv2.getStructuringElement(cv2.MORPH_CROSS, (3,3))
dilateimg = cv2.dilate(gBin,kernel,iterations = 3)

cv2_imshow(dilateimg)
# Out:
# <PIL.Image.Image image mode=L size=256x256>
